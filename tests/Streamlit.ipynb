# %%
import streamlit as st

# %%
st.title("我的第一个streamlit应用")
st.write("Hello!World!")
# Out:
# 2026-05-18 10:46:51.831 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-18 10:46:52.539
# ...
#   command:
#
#     streamlit run D:\Anaconda\envs\Knowledge_graph\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-18 10:46:52.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-18 10:46:52.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-18 10:46:52.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-18 10:46:52.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-18 10:46:52.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ---

# %%
from neo4j import GraphDatabase

# 测试连接
uri = "bolt://192.168.100.128:7687"
user = "neo4j"
password = "hr.sUqm9B75C.sK"  # 替换为你的密码

try:
    driver = GraphDatabase.driver(uri, auth=(user, password))
    driver.verify_connectivity()
    print("✅ 连接成功！")
    driver.close()
except Exception as e:
    print(f"❌ 连接失败：{e}")
# Out:
# ✅ 连接成功！

# %%
import os
ext = os.path.splitext(r"D:\python1.0\Knowledge_graph\data\triplets.csv")
ext
# Out:
# ('D:\\python1.0\\Knowledge_graph\\data\\triplets', '.csv')

# %%
import re
text =("我就是太阳！卧槽\n我是奶  酪  ，  不是吧兄弟？ai。")
parts = re.split(r'[，。；！？\n,;!?]', text)
print(parts[3].strip())
print(parts[3])
# Out:
# 不是吧兄弟
#   不是吧兄弟

# %%
sentence = "我们不仅是太阳，我者你"
m = re.match(r'^([\u4e00-\u9fff\w]{2,20}?)(?:不仅|不但|不光|不单)?(?:是|有|在|位于|担任|总部|研发|开发|推出|生产|投资|收购|创立|创办|创建|成立|属于|隶属|合作|联合)', sentence)
m.group(1)
m.group(0)
# Out:
# '我们不仅是'

# %%
# Out:
# 0
